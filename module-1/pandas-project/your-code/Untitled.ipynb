# %%
import json
import requests

# %%
import pandas as pd

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(10)
# Out:
#                                                actor            created_at  \
# 0  {'id': 49925263, 'login': 'Jpeck219', 'display...  2019-07-10T13:57:29Z
# 1  {'id': 42939509, 'login': 'mplebanski', 'displ...  2019-07-10T13:57:29Z
# 2  {'id': 25160792, 'login': 'kopano-bot', 'displ...  2019-07-10T13:57:29Z
# 3  {'id': 44447832, 'login': 'tdeverx', 'display_...  2019-07-10T13:57:29Z
# 4  {'id': 17193977, 'login': 'newstools', 'displa...  2019-07-10T13:57:29Z
# 5  {'id': 11837591, 'login': 'jptaylor226', 'disp...  2019-07-10T13:57:29Z
# 6  {'id': 5467972, 'login': 'jozzi', 'display_log...  2019-07-10T13:57:29Z
# 7  {'id': 32922263, 'login': 'zahirahmed', 'displ...  2019-07-10T13:57:29Z
# 8  {'id': 12370585, 'login': 'MiRinZhang', 'displ...  2019-07-10T13:57:29Z
# 9  {'id': 12501819, 'login': 'dambusm', 'display_...  2019-07-10T13:57:29Z
#
#            id                                                org  \
# 0  9984144397                                                NaN
# 1  9984144398  {'id': 23193179, 'login': 'golemfactory', 'gra...
# 2  9984144394  {'id': 25119601, 'login': 'Kopano-dev', 'grava...
# 3  9984144390                                                NaN
# 4  9984144388                                                NaN
# 5  9984144369                                                NaN
# 6  9984144374  {'id': 38202270, 'login': 'operator-framework'...
# 7  9984144365                                                NaN
# 8  9984144357  {'id': 35187521, 'login': 'WeMediaChain', 'gra...
# 9  9984144356  {'id': 23617963, 'login': 'sveltejs', 'gravata...
#
#                                              payload  public  \
# 0  {'push_id': 3802057649, 'size': 1, 'distinct_s...    True
# 1  {'push_id': 3802057650, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 3802057645, 'size': 2, 'distinct_s...    True
# 3  {'push_id': 3802057648, 'size': 1, 'distinct_s...    True
# 4  {'push_id': 3802057644, 'size': 1, 'distinct_s...    True
# 5  {'push_id': 3802057633, 'size': 1, 'distinct_s...    True
# 6  {'action': 'opened', 'number': 155, 'pull_requ...    True
# 7  {'push_id': 3802057578, 'size': 1, 'distinct_s...    True
# 8  {'action': 'created', 'issue': {'url': 'https:...    True
# 9                              {'action': 'started'}    True
#
#                                                 repo               type
# 0  {'id': 193951699, 'name': 'Jpeck219/dsc-web-sc...          PushEvent
# 1  {'id': 46433937, 'name': 'golemfactory/golem',...          PushEvent
# 2  {'id': 89251351, 'name': 'Kopano-dev/kopano-we...          PushEvent
# 3  {'id': 173206147, 'name': 'tdeverx/shortcuts',...          PushEvent
# 4  {'id': 163731155, 'name': 'newstools/2019-the-...          PushEvent
# 5  {'id': 180232996, 'name': 'jptaylor226/CodeSam...          PushEvent
# 6  {'id': 167203330, 'name': 'operator-framework/...   PullRequestEvent
# 7  {'id': 195752500, 'name': 'zahirahmed/CargoCus...          PushEvent
# 8  {'id': 116546908, 'name': 'WeMediaChain/websit...  IssueCommentEvent
# 9  {'id': 74293321, 'name': 'sveltejs/svelte', 'u...         WatchEvent

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['actor'])
# Out:
# {0: {'id': 49925263,
#   'login': 'Jpeck219',
#   'display_login': 'Jpeck219',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Jpeck219',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/49925263?'},
#  1: {'id': 42939509,
#   'login': 'mplebanski',
#   'display_login': 'mplebanski',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mplebanski',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/42939509?'},
#  2: {'id': 25160792,
#   'login': 'kopano-bot',
#   'display_login': 'kopano-bot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kopano-bot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/25160792?'},
#  3: {'id': 44447832,
#   'login': 'tdeverx',
#   'display_login': 'tdeverx',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tdeverx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44447832?'},
#  4: {'id': 17193977,
#   'login': 'newstools',
#   'display_login': 'newstools',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/newstools',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/17193977?'},
#  5: {'id': 11837591,
#   'login': 'jptaylor226',
#   'display_login': 'jptaylor226',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jptaylor226',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/11837591?'},
#  6: {'id': 5467972,
#   'login': 'jozzi',
#   'display_login': 'jozzi',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jozzi',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/5467972?'},
#  7: {'id': 32922263,
#   'login': 'zahirahmed',
#   'display_login': 'zahirahmed',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/zahirahmed',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/32922263?'},
#  8: {'id': 12370585,
#   'login': 'MiRinZhang',
#   'display_login': 'MiRinZhang',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MiRinZhang',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/12370585?'},
#  9: {'id': 12501819,
#   'login': 'dambusm',
#   'display_login': 'dambusm',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dambusm',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/12501819?'},
#  10: {'id': 51573409,
#   'login': 'Asahi18',
#   'display_login': 'Asahi18',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Asahi18',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/51573409?'},
#  11: {'id': 21987477,
#   'login': 'Pishoy',
#   'display_login': 'Pishoy',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Pishoy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/21987477?'},
#  12: {'id': 22169029,
#   'login': 'speedtracker-bot',
#   'display_login': 'speedtracker-bot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/speedtracker-bot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/22169029?'},
#  13: {'id': 25261223,
#   'login': 'reomreven',
#   'display_login': 'reomreven',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/reomreven',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/25261223?'},
#  14: {'id': 10450325,
#   'login': 'voquanghoa',
#   'display_login': 'voquanghoa',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/voquanghoa',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10450325?'},
#  15: {'id': 4489226,
#   'login': 'aksenoff',
#   'display_login': 'aksenoff',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/aksenoff',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/4489226?'},
#  16: {'id': 21987477,
#   'login': 'Pishoy',
#   'display_login': 'Pishoy',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Pishoy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/21987477?'},
#  17: {'id': 39111822,
#   'login': 'PLThabangR',
#   'display_login': 'PLThabangR',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/PLThabangR',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/39111822?'},
#  18: {'id': 52697534,
#   'login': 'Denis-Alexeev',
#   'display_login': 'Denis-Alexeev',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Denis-Alexeev',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/52697534?'},
#  19: {'id': 6355253,
#   'login': 'JasonM16',
#   'display_login': 'JasonM16',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/JasonM16',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6355253?'},
#  20: {'id': 1674891,
#   'login': 'davidecaroselli',
#   'display_login': 'davidecaroselli',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/davidecaroselli',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1674891?'},
#  21: {'id': 4489226,
#   'login': 'aksenoff',
#   'display_login': 'aksenoff',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/aksenoff',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/4489226?'},
#  22: {'id': 26709214,
#   'login': 'SnehaPaulson',
#   'display_login': 'SnehaPaulson',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/SnehaPaulson',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/26709214?'},
#  23: {'id': 10308689,
#   'login': 'matlus',
#   'display_login': 'matlus',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/matlus',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10308689?'},
#  24: {'id': 7911619,
#   'login': 'miswanting',
#   'display_login': 'miswanting',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/miswanting',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7911619?'},
#  25: {'id': 52719124,
#   'login': 'Abhkk9',
#   'display_login': 'Abhkk9',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Abhkk9',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/52719124?'},
#  26: {'id': 47058692,
#   'login': 'DeathkV20',
#   'display_login': 'DeathkV20',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/DeathkV20',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/47058692?'},
#  27: {'id': 32014946,
#   'login': 'uasier',
#   'display_login': 'uasier',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/uasier',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/32014946?'},
#  28: {'id': 17265214,
#   'login': 'code36u4r60',
#   'display_login': 'code36u4r60',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/code36u4r60',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/17265214?'},
#  29: {'id': 50410836,
#   'login': 'stbollen',
#   'display_login': 'stbollen',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/stbollen',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/50410836?'}}

# %%
pd.DataFrame(dict(data['actor']))
# Out:
#                                                               0   \
# avatar_url     https://avatars.githubusercontent.com/u/49925263?
# display_login                                           Jpeck219
# gravatar_id
# id                                                      49925263
# login                                                   Jpeck219
# url                        https://api.github.com/users/Jpeck219
#
#                                                               1   \
# avatar_url     https://avatars.githubusercontent.com/u/42939509?
# display_login                                         mplebanski
# gravatar_id
# id                                                      42939509
# login                                                 mplebanski
# url                      https://api.github.com/users/mplebanski
#
#                                                               2   \
# avatar_url     https://avatars.githubusercontent.com/u/25160792?
# display_login                                         kopano-bot
# gravatar_id
# id                                                      25160792
# login                                                 kopano-bot
# url                      https://api.github.com/users/kopano-bot
#
#                                                               3   \
# avatar_url     https://avatars.githubusercontent.com/u/44447832?
# display_login                                            tdeverx
# gravatar_id
# id                                                      44447832
# login                                                    tdeverx
# url                         https://api.github.com/users/tdeverx
#
#                                                               4   \
# avatar_url     https://avatars.githubusercontent.com/u/17193977?
# display_login                                          newstools
# gravatar_id
# id                                                      17193977
# login                                                  newstools
# url                       https://api.github.com/users/newstools
#
#                                                               5   \
# avatar_url     https://avatars.githubusercontent.com/u/11837591?
# display_login                                        jptaylor226
# gravatar_id
# id                                                      11837591
# login                                                jptaylor226
# url                     https://api.github.com/users/jptaylor226
#
#                                                              6   \
# avatar_url     https://avatars.githubusercontent.com/u/5467972?
# display_login                                             jozzi
# gravatar_id
# id                                                      5467972
# login                                                     jozzi
# url                          https://api.github.com/users/jozzi
#
#                                                               7   \
# avatar_url     https://avatars.githubusercontent.com/u/32922263?
# display_login                                         zahirahmed
# gravatar_id
# id                                                      32922263
# login                                                 zahirahmed
# url                      https://api.github.com/users/zahirahmed
#
#                                                               8   \
# avatar_url     https://avatars.githubusercontent.com/u/12370585?
# display_login                                         MiRinZhang
# gravatar_id
# id                                                      12370585
# login                                                 MiRinZhang
# url                      https://api.github.com/users/MiRinZhang
#
#                                                               9   ...  \
# avatar_url     https://avatars.githubusercontent.com/u/12501819?  ...
# display_login                                            dambusm  ...
# gravatar_id                                                       ...
# id                                                      12501819  ...
# login                                                    dambusm  ...
# url                         https://api.github.com/users/dambusm  ...
#
#                                                              20  \
# avatar_url     https://avatars.githubusercontent.com/u/1674891?
# display_login                                   davidecaroselli
# gravatar_id
# id                                                      1674891
# login                                           davidecaroselli
# url                https://api.github.com/users/davidecaroselli
#
#                                                              21  \
# avatar_url     https://avatars.githubusercontent.com/u/4489226?
# display_login                                          aksenoff
# gravatar_id
# id                                                      4489226
# login                                                  aksenoff
# url                       https://api.github.com/users/aksenoff
#
#                                                               22  \
# avatar_url     https://avatars.githubusercontent.com/u/26709214?
# display_login                                       SnehaPaulson
# gravatar_id
# id                                                      26709214
# login                                               SnehaPaulson
# url                    https://api.github.com/users/SnehaPaulson
#
#                                                               23  \
# avatar_url     https://avatars.githubusercontent.com/u/10308689?
# display_login                                             matlus
# gravatar_id
# id                                                      10308689
# login                                                     matlus
# url                          https://api.github.com/users/matlus
#
#                                                              24  \
# avatar_url     https://avatars.githubusercontent.com/u/7911619?
# display_login                                        miswanting
# gravatar_id
# id                                                      7911619
# login                                                miswanting
# url                     https://api.github.com/users/miswanting
#
#                                                               25  \
# avatar_url     https://avatars.githubusercontent.com/u/52719124?
# display_login                                             Abhkk9
# gravatar_id
# id                                                      52719124
# login                                                     Abhkk9
# url                          https://api.github.com/users/Abhkk9
#
#                                                               26  \
# avatar_url     https://avatars.githubusercontent.com/u/47058692?
# display_login                                          DeathkV20
# gravatar_id
# id                                                      47058692
# login                                                  DeathkV20
# url                       https://api.github.com/users/DeathkV20
#
#                                                               27  \
# avatar_url     https://avatars.githubusercontent.com/u/32014946?
# display_login                                             uasier
# gravatar_id
# id                                                      32014946
# login                                                     uasier
# url                          https://api.github.com/users/uasier
#
#                                                               28  \
# avatar_url     https://avatars.githubusercontent.com/u/17265214?
# display_login                                        code36u4r60
# gravatar_id
# id                                                      17265214
# login                                                code36u4r60
# url                     https://api.github.com/users/code36u4r60
#
#                                                               29
# avatar_url     https://avatars.githubusercontent.com/u/50410836?
# display_login                                           stbollen
# gravatar_id
# id                                                      50410836
# login                                                   stbollen
# url                        https://api.github.com/users/stbollen
#
# [6 rows x 30 columns]

# %%
pd.DataFrame(dict(data['actor'])).transpose()
# Out:
#                                            avatar_url     display_login  \
# 0   https://avatars.githubusercontent.com/u/49925263?          Jpeck219
# 1   https://avatars.githubusercontent.com/u/42939509?        mplebanski
# 2   https://avatars.githubusercontent.com/u/25160792?        kopano-bot
# 3   https://avatars.githubusercontent.com/u/44447832?           tdeverx
# 4   https://avatars.githubusercontent.com/u/17193977?         newstools
# 5   https://avatars.githubusercontent.com/u/11837591?       jptaylor226
# 6    https://avatars.githubusercontent.com/u/5467972?             jozzi
# 7   https://avatars.githubusercontent.com/u/32922263?        zahirahmed
# 8   https://avatars.githubusercontent.com/u/12370585?        MiRinZhang
# 9   https://avatars.githubusercontent.com/u/12501819?           dambusm
# 10  https://avatars.githubusercontent.com/u/51573409?           Asahi18
# 11  https://avatars.githubusercontent.com/u/21987477?            Pishoy
# 12  https://avatars.githubusercontent.com/u/22169029?  speedtracker-bot
# 13  https://avatars.githubusercontent.com/u/25261223?         reomreven
# 14  https://avatars.githubusercontent.com/u/10450325?        voquanghoa
# 15   https://avatars.githubusercontent.com/u/4489226?          aksenoff
# 16  https://avatars.githubusercontent.com/u/21987477?            Pishoy
# 17  https://avatars.githubusercontent.com/u/39111822?        PLThabangR
# 18  https://avatars.githubusercontent.com/u/52697534?     Denis-Alexeev
# 19   https://avatars.githubusercontent.com/u/6355253?          JasonM16
# 20   https://avatars.githubusercontent.com/u/1674891?   davidecaroselli
# 21   https://avatars.githubusercontent.com/u/4489226?          aksenoff
# 22  https://avatars.githubusercontent.com/u/26709214?      SnehaPaulson
# 23  https://avatars.githubusercontent.com/u/10308689?            matlus
# 24   https://avatars.githubusercontent.com/u/7911619?        miswanting
# 25  https://avatars.githubusercontent.com/u/52719124?            Abhkk9
# 26  https://avatars.githubusercontent.com/u/47058692?         DeathkV20
# 27  https://avatars.githubusercontent.com/u/32014946?            uasier
# 28  https://avatars.githubusercontent.com/u/17265214?       code36u4r60
# 29  https://avatars.githubusercontent.com/u/50410836?          stbollen
#
#    gravatar_id        id             login  \
# 0               49925263          Jpeck219
# 1               42939509        mplebanski
# 2               25160792        kopano-bot
# 3               44447832           tdeverx
# 4               17193977         newstools
# 5               11837591       jptaylor226
# 6                5467972             jozzi
# 7               32922263        zahirahmed
# 8               12370585        MiRinZhang
# 9               12501819           dambusm
# 10              51573409           Asahi18
# 11              21987477            Pishoy
# 12              22169029  speedtracker-bot
# 13              25261223         reomreven
# 14              10450325        voquanghoa
# 15               4489226          aksenoff
# 16              21987477            Pishoy
# 17              39111822        PLThabangR
# 18              52697534     Denis-Alexeev
# 19               6355253          JasonM16
# 20               1674891   davidecaroselli
# 21               4489226          aksenoff
# 22              26709214      SnehaPaulson
# 23              10308689            matlus
# 24               7911619        miswanting
# 25              52719124            Abhkk9
# 26              47058692         DeathkV20
# 27              32014946            uasier
# 28              17265214       code36u4r60
# 29              50410836          stbollen
#
#                                               url
# 0           https://api.github.com/users/Jpeck219
# 1         https://api.github.com/users/mplebanski
# 2         https://api.github.com/users/kopano-bot
# 3            https://api.github.com/users/tdeverx
# 4          https://api.github.com/users/newstools
# 5        https://api.github.com/users/jptaylor226
# 6              https://api.github.com/users/jozzi
# 7         https://api.github.com/users/zahirahmed
# 8         https://api.github.com/users/MiRinZhang
# 9            https://api.github.com/users/dambusm
# 10           https://api.github.com/users/Asahi18
# 11            https://api.github.com/users/Pishoy
# 12  https://api.github.com/users/speedtracker-bot
# 13         https://api.github.com/users/reomreven
# 14        https://api.github.com/users/voquanghoa
# 15          https://api.github.com/users/aksenoff
# 16            https://api.github.com/users/Pishoy
# 17        https://api.github.com/users/PLThabangR
# 18     https://api.github.com/users/Denis-Alexeev
# 19          https://api.github.com/users/JasonM16
# 20   https://api.github.com/users/davidecaroselli
# 21          https://api.github.com/users/aksenoff
# 22      https://api.github.com/users/SnehaPaulson
# 23            https://api.github.com/users/matlus
# 24        https://api.github.com/users/miswanting
# 25            https://api.github.com/users/Abhkk9
# 26         https://api.github.com/users/DeathkV20
# 27            https://api.github.com/users/uasier
# 28       https://api.github.com/users/code36u4r60
# 29          https://api.github.com/users/stbollen

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)
flat.head(10)
# Out:
#              created_at          id  public               type  \
# 0  2019-07-10T13:57:29Z  9984144397    True          PushEvent
# 1  2019-07-10T13:57:29Z  9984144398    True          PushEvent
# 2  2019-07-10T13:57:29Z  9984144394    True          PushEvent
# 3  2019-07-10T13:57:29Z  9984144390    True          PushEvent
# 4  2019-07-10T13:57:29Z  9984144388    True          PushEvent
# 5  2019-07-10T13:57:29Z  9984144369    True          PushEvent
# 6  2019-07-10T13:57:29Z  9984144374    True   PullRequestEvent
# 7  2019-07-10T13:57:29Z  9984144365    True          PushEvent
# 8  2019-07-10T13:57:29Z  9984144357    True  IssueCommentEvent
# 9  2019-07-10T13:57:29Z  9984144356    True         WatchEvent
#
#                                     actor_avatar_url actor_display_login  \
# 0  https://avatars.githubusercontent.com/u/49925263?            Jpeck219
# 1  https://avatars.githubusercontent.com/u/42939509?          mplebanski
# 2  https://avatars.githubusercontent.com/u/25160792?          kopano-bot
# 3  https://avatars.githubusercontent.com/u/44447832?             tdeverx
# 4  https://avatars.githubusercontent.com/u/17193977?           newstools
# 5  https://avatars.githubusercontent.com/u/11837591?         jptaylor226
# 6   https://avatars.githubusercontent.com/u/5467972?               jozzi
# 7  https://avatars.githubusercontent.com/u/32922263?          zahirahmed
# 8  https://avatars.githubusercontent.com/u/12370585?          MiRinZhang
# 9  https://avatars.githubusercontent.com/u/12501819?             dambusm
#
#   actor_gravatar_id  actor_id  actor_login  \
# 0                    49925263     Jpeck219
# 1                    42939509   mplebanski
# 2                    25160792   kopano-bot
# 3                    44447832      tdeverx
# 4                    17193977    newstools
# 5                    11837591  jptaylor226
# 6                     5467972        jozzi
# 7                    32922263   zahirahmed
# 8                    12370585   MiRinZhang
# 9                    12501819      dambusm
#
#                                   actor_url  ... payload_number  \
# 0     https://api.github.com/users/Jpeck219  ...            NaN
# 1   https://api.github.com/users/mplebanski  ...            NaN
# 2   https://api.github.com/users/kopano-bot  ...            NaN
# 3      https://api.github.com/users/tdeverx  ...            NaN
# 4    https://api.github.com/users/newstools  ...            NaN
# 5  https://api.github.com/users/jptaylor226  ...            NaN
# 6        https://api.github.com/users/jozzi  ...            155
# 7   https://api.github.com/users/zahirahmed  ...            NaN
# 8   https://api.github.com/users/MiRinZhang  ...            NaN
# 9      https://api.github.com/users/dambusm  ...            NaN
#
#                                 payload_pull_request payload_push_id  \
# 0                                                NaN      3802057649
# 1                                                NaN      3802057650
# 2                                                NaN      3802057645
# 3                                                NaN      3802057648
# 4                                                NaN      3802057644
# 5                                                NaN      3802057633
# 6  {'url': 'https://api.github.com/repos/operator...             NaN
# 7                                                NaN      3802057578
# 8                                                NaN             NaN
# 9                                                NaN             NaN
#
#   payload_pusher_type                                     payload_ref  \
# 0                 NaN                                  refs/heads/wip
# 1                 NaN  refs/heads/mplebanski-patch-benchmark-crashing
# 2                 NaN                               refs/heads/master
# 3                 NaN                               refs/heads/master
# 4                 NaN                               refs/heads/master
# 5                 NaN                               refs/heads/master
# 6                 NaN                                             NaN
# 7                 NaN                               refs/heads/master
# 8                 NaN                                             NaN
# 9                 NaN                                             NaN
#
#   payload_ref_type payload_size    repo_id  \
# 0              NaN            1  193951699
# 1              NaN            1   46433937
# 2              NaN            2   89251351
# 3              NaN            1  173206147
# 4              NaN            1  163731155
# 5              NaN            1  180232996
# 6              NaN          NaN  167203330
# 7              NaN            1  195752500
# 8              NaN          NaN  116546908
# 9              NaN          NaN   74293321
#
#                                      repo_name  \
# 0  Jpeck219/dsc-web-scraping-lab-nyc-ds-060319
# 1                           golemfactory/golem
# 2                     Kopano-dev/kopano-webapp
# 3                            tdeverx/shortcuts
# 4          newstools/2019-the-guardian-nigeria
# 5                      jptaylor226/CodeSamples
# 6            operator-framework/operatorhub.io
# 7                  zahirahmed/CargoCustomerApp
# 8                         WeMediaChain/website
# 9                              sveltejs/svelte
#
#                                             repo_url
# 0  https://api.github.com/repos/Jpeck219/dsc-web-...
# 1    https://api.github.com/repos/golemfactory/golem
# 2  https://api.github.com/repos/Kopano-dev/kopano...
# 3     https://api.github.com/repos/tdeverx/shortcuts
# 4  https://api.github.com/repos/newstools/2019-th...
# 5  https://api.github.com/repos/jptaylor226/CodeS...
# 6  https://api.github.com/repos/operator-framewor...
# 7  https://api.github.com/repos/zahirahmed/CargoC...
# 8  https://api.github.com/repos/WeMediaChain/website
# 9       https://api.github.com/repos/sveltejs/svelte
#
# [10 rows x 34 columns]
