# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

import urllib
import urllib.request
from urllib.request import urlopen
import random
import re

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Toy_Story_characters'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Toy Story characters - Wikipedia
#   </title>
#   <script>
# ...

# %%
tags = ['h4']
text = [element.text for element in soup.find_all(tags)]
text[:40]

df = pd.DataFrame(text[0:])
df.columns = ['Toy Story characters']
df = df['Toy Story characters'].map(lambda x: x.split('[')[0])
pd.DataFrame(df)
# Out:
#                Toy Story characters
# 0                     Sheriff Woody
# 1                    Buzz Lightyear
# 2                           Bo Peep
# 3                   Mr. Potato Head
# 4                        Slinky Dog
# 5                               Rex
# 6                              Hamm
# 7   Sarge and the Bucket O Soldiers
# 8                                RC
# 9                 Andy's other toys
# 10                       Andy Davis
# 11                       Mrs. Davis
# 12                      Molly Davis
# 13                     Sid Phillips
# 14                  Hannah Phillips
# 15            Sid and Hannah's toys
# 16                             Scud
# 17                           Jessie
# 18                         Bullseye
# 19       Stinky Pete the Prospector
# 20      Utility Belt Buzz Lightyear
# 21                Evil Emperor Zurg
# 22                Tour Guide Barbie
# 23         Rock 'Em Sock 'Em Robots
# 24             Lots-O'-Huggin' Bear
# ...

# %%
df.to_csv('/Users/admin/Documents/data-labs/module-1/web-project/your-code/Output/web-outputs.csv', sep=',')
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
